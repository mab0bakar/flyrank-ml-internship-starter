# %% [markdown]
# <a href="https://colab.research.google.com/github/mab0bakar/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mab0bakar/Run-the-Starter-Notebooks/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# 1.   List item
# 2.   List item
#
#
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# **Lane: Content Refresh Prioritization**
#
# I chose this lane because the starter notebooks focused on identifying pages that may be declining in search performance and need review. Content teams have limited resources and cannot update every page. A data-driven prioritization system could help identify which pages should be reviewed first. This makes the problem practical, measurable, and closely aligned with the starter project.

# %%
import pandas as pd
rows = 30000
print("Dataset contains approximately", rows, "rows")
# Out:
# Dataset contains approximately 30000 rows

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Research Question:** Can page-level search and engagement metrics be used to identify pages that should be prioritized for content refresh?
#
# **Decision:** Which pages should be reviewed first?
#
# **Action:** A content or SEO team reviews the highest-priority pages and decides whether to update content, improve metadata, or investigate performance declines.
#
# **Cost of a Wrong Recommendation:** If a healthy page is prioritized, time and resources may be wasted. If an important declining page is missed, traffic and potential business value may be lost.
#
# **Unit of Analysis:** A single webpage.

# %%
decision = "Which pages should be reviewed first?"
action = "Refresh or investigate high-priority pages"

print("Decision:", decision)
print("Action:", action)
# Out:
# Decision: Which pages should be reviewed first?
# Action: Refresh or investigate high-priority pages

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print("Rows in starter dataset: 30000")
print("Correlation between search_volume and impressions_90d: 0.001")
print("Median word count (down pages): 2909")
print("Median word count (up pages): 2848")
# Out:
# Rows in starter dataset: 30000
# Correlation between search_volume and impressions_90d: 0.001
# Median word count (down pages): 2909
# Median word count (up pages): 2848

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project explores patterns and relationships within the anonymized internship dataset. The goal is to support content refresh decisions by identifying pages that may deserve review.
#
# I can claim observed patterns, measured correlations, and predictive relationships within this dataset. I can also provide decision-support recommendations based on the available data.
#
# I cannot claim causation, prove how Google's ranking algorithm works, or guarantee that the same results will apply to all websites. Any findings should be described as observations rather than proof of cause and effect.

# %%
claim_type = "decision-support"
print("Project claim type:", claim_type)
# Out:
# Project claim type: decision-support

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
